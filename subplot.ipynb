# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-5,5,11)
y = x**2

# %%
plt.subplot(
    1,# filas
    2, # columnas
    1 #index
    )
plt.plot(x,y)
plt.subplot(
    1,# filas
    2, # columnas
    2 #index
    )
plt.hist(y)
plt.show()

# %%
plt.subplot(
    1,# filas
    2, # columnas
    1 #index
    )
plt.plot(x,y)
plt.plot(y,x,'r--')
plt.subplot(
    1,# filas
    2, # columnas
    2 #index
    )
plt.pie(y)
plt.show()

# %%
plt.subplot(
    2,# filas
    1, # columnas
    1 #index
    )
plt.plot(x,y)
plt.plot(y,x,'r--')
plt.subplot(
    2,# filas
    1, # columnas
    2 #index
    )
plt.pie(y)
plt.show()
