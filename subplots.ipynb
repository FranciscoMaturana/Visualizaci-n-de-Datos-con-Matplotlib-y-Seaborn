# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-5,5,21)
y = np.sin(x)

# %%
fig, axes = plt.subplots()
axes.plot(x,y,'b--')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].plot(x,y,'b--')
axes[1].boxplot(y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f3913a55490>,
#   <matplotlib.lines.Line2D at 0x7f3913a56150>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f3913a56cd0>,
#   <matplotlib.lines.Line2D at 0x7f3913a57690>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f3913a2cf50>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f3913a64210>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f3913a56490>],
#  'means': []}

# %%
fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2)
ax1.plot(x,y,'b--')
ax2.boxplot(y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f39139340d0>,
#   <matplotlib.lines.Line2D at 0x7f3913934b90>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f3913935710>,
#   <matplotlib.lines.Line2D at 0x7f3913936250>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f3913927490>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f3913936d50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f3913a67750>],
#  'means': []}

# %%
fig, axes = plt.subplots(nrows=2, ncols=4)
axes[0][0].plot(x,np.cos(x))
axes[0][1].plot(x,np.sin(x),'r')
axes[0][2].plot(x,np.tan(x),'y')
axes[0][3].plot(x,np.cos(x)**2,'--')

# %%
fig, ((ax1,ax2,ax3,ax4),(ax5,ax6,ax7,ax8)) = plt.subplots(nrows=2, ncols=4)
ax1.plot(x,np.cos(x))
ax2.plot(x,np.sin(x),'r')
ax3.plot(x,np.tan(x),'y')
ax4.plot(x,np.cos(x)**2,'--')

ax5.plot(x,np.cos(y))
ax6.plot(x,np.sin(y),'r')
ax7.plot(x,np.tan(y),'y')
ax8.plot(x,np.cos(y)**2,'--')

fig.tight_layout()
